# %%
## data injection
# text, pdf, webpage

from langchain_community.document_loaders import TextLoader

loader = TextLoader(r"C:\D\old_laptop_stuff\DL4CV\gen_ai\agentic_ai\RAG\speach.txt")
text_documents = loader.load()
text_documents
# Out:
# c:\D\old_laptop_stuff\DL4CV\gen_ai\agentic_ai\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# [Document(metadata={'source': 'C:\\D\\old_laptop_stuff\\DL4CV\\gen_ai\\agentic_ai\\RAG\\speach.txt'}, page_content="This day reminds us of the sacrifices of our brave freedom fighters and the vision of our great leaders. We should always follow the values of unity, equality, and respect for our nation. Let us promise to be good citizens and work for India's progress. Thank you, and Happy Republic Day!")]

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
from urllib.parse import quote

url = "https://en.wikipedia.org/wiki/Republic_Day_(India)"
encoded_url = quote(url, safe=':/')

loader = WebBaseLoader(encoded_url) 
web_documents = loader.load()
web_documents
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Republic_Day_%28India%29', 'title': 'Republic Day (India) - Wikipedia', 'language': 'en'}, page_content='\n\n\n\nRepublic Day (India) - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nBackground\n\n\n\n\n\n\n\n\n2\nCustoms and celebrations\n\n\n\n\nToggle Customs and celebrations subsection\n\n\n\n\n\n2.1\nParade\n\n\n\n\n\n\n\n\n2.2\nFlypast\n\n\n\n\n\n\n2.2.1\nChief-guest\n\n\n\n\n\n\n\n\n\n\n2.3\nBeating retreat\n\n\n\n\n\n\n\n\n2.4\nAwards\n\n\n\n\n\n\n\n\n\n\n3\nGallery\n\n\n\n\n\n\n\n\n4\nSee also\n\n\n\n\n\n\n\n\n5\nReferences\n\n\n\n\n\n\n\n\n6\nExternal links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\nRepublic Day (India)\n\n\n\n49 languages\n\n\n\n\nAfrikaansالعربيةঅসমীয়াবাংলাБеларускаяभोजपुरीCatalàČeštinaDeutschΕλληνικάEspañolEsperantoفارسیFrançaisગુજરાતી한국어Հայերենहिन्दीBahasa IndonesiaItalianoעבריתಕನ್ನಡکٲشُرമലയാളംमराठीBahasa Melayuनेपाली日本語Norsk bokmålଓଡ଼ିଆਪੰਜਾਬੀپنجابیPolskiPortuguêsRomânăРусскийसंस्कृतम्ᱥᱟᱱᱛᱟᱲᱤSimple EnglishSuomiSvenskaதமிழ்తెలుగుತುಳುTürkçeУкраїнськаاردوTiếng Việt中文\n\nEdit links\n\n\n\n\n\n\n\n\n\n\n\nArticleTalk\n\n\n\n\n\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nReadEditView history\n\n\n\n\n\n\n\nTools\n\n\n\n\n\nTools\nmove to sidebar\nhide\n\n\n\n\t\tActions\n\t\n\n\nReadEditView history\n\n\n\n\n\n\t\tGeneral\n\t\n\n\nWhat links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code\n\n\n\n\n\n\t\tPrint/export\n\t\n\n\nDownload as PDFPrintable version\n\n\n\n\n\n\t\tIn other projects\n\t\n\n\nWikimedia CommonsWikidata item\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\nmove to sidebar\nhide\n\n\n\n\n\n\n\n\n\n\nFrom Wikipedia, the free encyclopedia\n\n\n\nNational day of India celebrating the adoption of its Constitution (26 January)\n\n\nRepublic Day of IndiaThe original text of the Preamble to the Constitution of India. The Constitution of India came into force on 26\xa0January\xa01950\xa0(1950-01-26).Observed\xa0byRepublic of IndiaTypePublicSignificanceCommemorates the adoption of India’s ConstitutionCelebrationsParades, speeches and cultural events etc.Date26 JanuaryNext\xa0time26 January 2026\xa0(2026-01-26)FrequencyAnnualFirst\xa0time26\xa0January 1950 (75 years ago)\xa0(1950-01-26)\nPart of the Politics series onRepublicanism\nConcepts\nAnti-monarchism\nAnti-corruption\nCivic virtue\nCivil society\nConsent of the governed\nDemocracy\nDemocratization\nLiberty as non-domination\nMixed government\nPolitical representation\nPopular sovereignty\nPublic participation\nRepublic\nRes publica\nRule of law\nSelf-governance\nSeparation of powers\nSocial contract\nSocial equality\n\nSchools\nGaullism\nJeffersonian democracy\nKantianism\nKemalism\nKhomeinism\nNasserism\nVenizelism\n\nTypes\nAutonomous\nCapitalist\nChristian\nClassical\nDemocratic\nFederal\nImperial\nIslamic\nMaritime\nModern\nParliamentary\nPeasant\nPeople\'s\nRevolutionary\nSecular\nSister\nSoviet\n\nPhilosophers\nArendt\nBaggini\nBello\nBentham\nBerlin\nBodin\nCattaneo\nChappell\nCicero\nCondorcet\nCrick\nFranklin\nHarrington\nHonderich\nJefferson\nKant\nLocke\nMachiavelli\nMadison\nMarx\nMazzini\nMill\nMontesquieu\nPaine\nPettit\nPolybius\nRousseau\nSandel\nSidney\nSkinner  ...
