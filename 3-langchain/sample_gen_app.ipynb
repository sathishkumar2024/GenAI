# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# api setups

os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %% [markdown]
# # Using OpenAI

# %% [markdown]
# # Using ollama

# %%
from langchain_community.llms import Ollama
import streamlit as st

# %% [markdown]
# 1. load Document

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
prompt = ChatPromptTemplate(
    [
        
        ("system", "You are a helpfull assitant. Please respond to the question asked"),
        ("user", "Question:{question}")
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 prompt = ChatPromptTemplate(
#       2     [
#       3
#       4         ("system", "You are a helpfull assitant. Please respond to the question asked"),
#       5         ("user", "Question:{question}")
#       6     ]
#       7 )
#
# NameError: name 'ChatPromptTemplate' is not defined
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 2. Text spliter / chunk the data
